# %%
import sys
sys.path.append('/home/diego/python/convolution-kernels-pytorch/')
from kernel.base import Kernel

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
t_ker = torch.arange(120)
values = torch.exp(-t_ker / 10)

kernel = Kernel(values=values, support=[0, 120])

x = torch.randn(1000, 1)
conv = kernel.convolve_continuous(x, trim=False)

# %%
plt.plot(x)
plt.plot(conv)

# %%
t_ker = torch.arange(-10, 10, 1)
values = torch.exp(-t_ker**2)

kernel = Kernel(values=values, support=[0, 120])

x = torch.randn(1000, 1)
conv = kernel.convolve_continuous(x, trim=False)

# %%
x.shape, kernel.values.shape, conv.shape
# Out:
# (torch.Size([1000, 1]), torch.Size([20, 1]), torch.Size([1019, 1]))

# %%
plt.plot(values)
